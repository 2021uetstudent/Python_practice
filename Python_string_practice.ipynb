# %% [markdown]
# **Words and Character Frequency Counter**

# %%
from collections import Counter
# Input the string from the user
text = input("")
lower_text = text.lower()
split_text = lower_text.split()
letter = [ ]
for ch in split_text:
    if (ch.isalpha()):
        letter.append(ch)
        word_frequecy = Counter(ch)
        print(word_frequecy)

letter_frequency = Counter(letter)
print(letter_frequency)
# Out:
# Counter({'a': 2, 'd': 1, 't': 1})
# Counter({'i': 1, 's': 1})
# Counter({'t': 2, 'i': 1, 'm': 1, 'p': 1, 'o': 1, 'r': 1, 'a': 1, 'n': 1})
# Counter({'a': 1, 'n': 1, 'd': 1})
# Counter({'a': 2, 'd': 1, 't': 1})
# Counter({'i': 1, 's': 1})
# Counter({'p': 1, 'o': 1, 'w': 1, 'e': 1, 'r': 1, 'f': 1, 'u': 1, 'l': 1})
# Counter({'data': 2, 'is': 2, 'important': 1, 'and': 1, 'powerful': 1})

# %% [markdown]
# **Vowel & Consonant Counter**

# %%
vowel = "aeiou"
input_str = input().lower()
v, con = 0,0
for ch in input_str:
    if ch in vowel:
        print(f"{ch} is vowel.")
        v= v+1  
    else:
        print(f"{ch} is consonant.")
        con= con +1
        
print(f"Total vowel character is {v} in {input_str}")
print(f"Total consonant in {input_str} is {con}")
# Out:
# d is consonant.
# a is vowel.
# t is consonant.
# a is vowel.
#   is consonant.
# i is vowel.
# s is consonant.
#   is consonant.
# p is consonant.
# o is vowel.
# w is consonant.
# e is vowel.
# r is consonant.
# f is consonant.
# u is vowel.
# l is consonant.
#   is consonant.
# n is consonant.
# o is vowel.
# w is consonant.
# a is vowel.
# d is consonant.
# a is vowel.
# y is consonant.
# s is consonant.
# Total vowel character is 9 in data is powerful nowadays
# Total consonant in data is powerful nowadays is 16

# %% [markdown]
# **Replace all vowel with #**

# %%
# Loop method
text = input()
vowel= "aeiouAEIOU"
new_text = " "
for ch in text:
    if (ch in vowel):
        new_text = new_text + "#"
    else:
        new_text = new_text + ch
print(new_text)

# without Loop method
no_vowel_text = (text.replace("a","#").replace("e","#").replace("i","#")
.replace("o","#").replace("u","#").replace("A","#").replace("E","#")
.replace("I","#").replace("O","#").replace("U","#"))
print(no_vowel_text)
# Out:
#  D#t# #s #mp#rt#nt
# D#t# #s #mp#rt#nt

# %% [markdown]
# **String Reverse**

# %%
name = input()
for i in range(1, len(name) + 1):
    reverse_str= name[-i]
    print(reverse_str)
# Out:
# t
# t
# u
# B
#
# a
# z
# i
# a
# F

# %% [markdown]
# **Reverse the word order**

# %%
input_string = input()
split_string = input_string.split()
reverse_words = split_string[::-1]
reverse_string = " ".join(reverse_words)
print(reverse_string)
# Out:
# fun is Python

# %% [markdown]
# **Palindrome Checker**

# %%
str_variable = input("Enter one word to check palindrome ")
valid_str = str_variable.lower()
if(valid_str[0:] == valid_str[::-1]):
    print(f"{valid_str} is palindrome.")
else:
    print(f"{valid_str} is not plaindrome.")

# %% [markdown]
# **sort all Character**

# %%
input_text = input()
sorted_text = " ".join(sorted(input_text))
print(sorted_text)
# Out:
#     f h i n n o p s t u y

# %% [markdown]
# **Anagram Checker**

# %%
word1 = input()
word2 = input()
sorted_word1= sorted(word1)
sorted_word2= sorted(word2)
if (Counter(sorted_word1) == Counter(sorted_word2)):
    print(f"{word1} and {word2} is Anagram.")
else:
    print(f"{word1} and {word2} is not Anagram")
# Out:
# act and listen is not Anagram

# %% [markdown]
# **Remove Duplicate Characters from a String**

# %%
sentence = input()
no_duplicate_char_sentence = " "
for ch in sentence:
    lower_char = ch.lower() 
    if (lower_char in no_duplicate_char_sentence):
        continue
    else:
        no_duplicate_char_sentence = no_duplicate_char_sentence + ch 
        print(no_duplicate_char_sentence)
# Out:
#  P
#  Pr
#  Pro
#  Prog
#  Proga
#  Progam
#  Progami
#  Progamin

# %% [markdown]
# **Title Case / Sentence Case Converter & Uppercase Converter**

# %%
input_txt = input()
tiltle_case_txt = input_text.title() 
print(f"The tiltle case output is: {tiltle_case_txt}")
upper_case_txt = input_text.upper()
print(f"The upper case output is: {upper_case_txt}")
# Out:
# The tiltle case output is: Python Is Fun
# The upper case output is: PYTHON IS FUN

# %% [markdown]
# **Maximum character (lexicographically) from the string**

# %%
txt1 = input()
txt2 = input()
txt3 = input()
max_char = max(txt1,txt2,txt3)
print(f"Maximum character from {txt1},{txt2},{txt3} is : {max_char}")
# Out:
# Maximum character from python ,is,fun is : python

# %% [markdown]
# **Count the total number of characters in the string (without len)**

# %%
# without loop method and length function
txt = input()
total_length = (txt.count("") - 1)
print(f"length of {txt}: {total_length}")

#with loop method
length = 0
for ch in txt:
    length = length + 1 
print(f"length of {txt}: {length}")
# Out:
# length of python is fun: 13
# length of python is fun: 13
